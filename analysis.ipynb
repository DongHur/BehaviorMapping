# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
store = pd.HDFStore("data_result/rat_data/Z2_2_Top-09062019132751/Z2_2_Top-09062019132751-0000DeepCut_resnet101_Tracking_mpOct5shuffle1_350000.h5")
df = store['/df_with_missing']
data = pd_data.to_numpy().reshape((len(df), -1, 3)).transpose((1,2,0))
(num_bp, num_dim, num_fr) = data.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-103-a99edc0c8ea3> in <module>
#       1 store = pd.HDFStore("data_result/rat_data/Z2_2_Top-09062019132751/Z2_2_Top-09062019132751-0000DeepCut_resnet101_Tracking_mpOct5shuffle1_350000.h5")
#       2 df = store['/df_with_missing']
# ----> 3 data = pd_data.to_numpy().reshape((len(df), -1, 3)).transpose((1,2,0))
#       4 (num_bp, num_dim, num_fr) = data.shape
#
# ValueError: cannot reshape array of size 45612 into shape (7307,newaxis,3)

# %%
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: data_result/rat_data/Z2_2_Top-09062019132751/Z2_2_Top-09062019132751-0000DeepCut_resnet101_Tracking_mpOct5shuffle1_350000.h5

# %%
pd.HDFStore("data_result/rat_data/Z2_2_Top-09062019132751/Z2_2_Top-09062019132751-0000DeepCut_resnet101_Tracking_mpOct5shuffle1_350000.h5")
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: data_result/rat_data/Z2_2_Top-09062019132751/Z2_2_Top-09062019132751-0000DeepCut_resnet101_Tracking_mpOct5shuffle1_350000.h5

# %%
# specify parameter
frame = 807
padding = 50
max_x, min_x = np.max(data[:,0,frame]), np.min(data[:,0,frame])
max_y, min_y = np.max(data[:,1,frame]), np.min(data[:,1,frame])
# plot bodypoint
plt.scatter(data[:,0,frame], data[:,1,frame], c=np.arange(num_bp))
plt.xlim(left=min_x-padding, right=max_x+padding)
plt.ylim(bottom=min_y-padding, top=max_y+padding)
plt.gca().set_aspect('equal', 'box')
plt.show()

# %%
store.close()

# %%
store.close()

# %%
num_bp
# Out:
# 12

# %%
# set center of axis as 7 and the angle of axis 9

# %%
store = pd.HDFStore("data_result/rat_data/Z2_2_Top-09062019132751/Z2_2_Top-09062019132751-0000DeepCut_resnet101_Tracking_mpOct5shuffle1_350000.h5")

# %%
store['/df_with_missing']
# Out:
# scorer    DeepCut_resnet101_Tracking_mpOct5shuffle1_350000               \
# bodyparts                                            snout
# coords                                                   x            y
# 0                                              1028.155007   214.697984
# 1                                              1026.813407   210.318883
# 2                                              1020.725886   212.515130
# 3                                              1018.446457   206.627349
# 4                                              1016.474681   201.215708
# 5                                              1020.328719   196.793880
# 6                                               990.550951   262.480714
# 7                                              1013.445375   220.231343
# 8                                              1011.498280   231.875737
# 9                                               988.303980   344.874803
# ...

# %%
data = np.load("data_result/rat_data/AON_C1_Top-09032019125129/BP_AON_C1_Top-09032019125129.npy")

# %%
# specify parameter
frame = 550
padding = 50
(num_bp, num_dim, num_fr) = data.shape
max_x, min_x = np.max(data[:,0,frame]), np.min(data[:,0,frame])
max_y, min_y = np.max(data[:,1,frame]), np.min(data[:,1,frame])
# plot bodypoint
plt.scatter(data[:,0,frame], data[:,1,frame], c=np.arange(num_bp))
plt.xlim(left=min_x-padding, right=max_x+padding)
plt.ylim(bottom=min_y-padding, top=max_y+padding)
plt.gca().set_aspect('equal', 'box')
plt.show()

# %%
rt_data = np.load("data_result/rat_data/AON_C1_Top-09032019125129/ROT_AON_C1_Top-09032019125129.npy")

# %%
data[9,0,frame]
# Out:
# -1.7763568394002505e-15

# %%
plt.plot(data[9,1,:])
plt.show()

# %%
bool(True)
# Out:
# True
